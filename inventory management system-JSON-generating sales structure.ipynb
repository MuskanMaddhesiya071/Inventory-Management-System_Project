# %%
## KEEPING THE TRACK OF THE SALE
import json
import time


f = open("inventory mgmt sys.json", "r")
js = f.read()
f.close()

record = json.loads(js)

print("--------------------MENU---------------------")
for key in record.keys():
    print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
    print("---------------------------------------------")
    print('')

ui_name=input("enter your name      : ")
ui_mail=input("enter your email    : ")
ui_ph=input("enter your phone number: ")

ui_pr = str(input("Enter product ID : "))
ui_qn = int(input("Enter Quantity   : "))


if record[ui_pr]["Qn"] >= ui_qn:
        record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
        print("--------------------------------------------")
        print("                BILL                        ")
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", ui_qn)
        print("---------------------------------------------")
        print("Billing Amount   : ", record[ui_pr]["Price"] * ui_qn, "Rs")
        print("---------------------------------------------")
        sale = '1'+","+ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+str(ui_qn * record[ui_pr]["Price"])+","+time.ctime()

        
else:
    print("Sorry, we do not have enough quantity")
    print("We have only", record[ui_pr]["Qn"], "quantity")
    print("---------------------------------------------")
    
    ch = input("Enter y/Y to purchase available stock and press n to leave ")
    
    if ch == "y" or ch == "Y":
        print("--------------------------------------------")
        print("                BILL                        ")
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", record[ui_pr]["Qn"])
        print("---------------------------------------------")
        print("Billing Amount   : ", record[ui_pr]["Price"] * record[ui_pr]["Qn"], "Rs")
        print("---------------------------------------------")
        
        
        record[ui_pr]['Qn'] = 0
        sale = '1'+","+ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(record[ui_pr]['Qn'])+","+str(record[ui_pr]["Price"])+","+str(record[ui_pr]['Qn'] * record[ui_pr]["Price"])+","+time.ctime()

        
        
    else:
        print("Thanks")

js = json.dumps(record)
f = open("inventory mgmt sys.json", "w")
f.write(js)
f.close()
# Out:
# --------------------MENU---------------------
# 1001 5 Star 10 195
# ---------------------------------------------
#
# 1002 Bar-One 20 0
# ---------------------------------------------
#
# 1003 Candy 2 0
# ---------------------------------------------
#
# 1004 Chocolate Cake 550 0
# ---------------------------------------------
#
# 1005 Blueberry Cake 650 0
# ---------------------------------------------
#
# enter your name      : muskan
# enter your email    : musknan@gmail.com
# enter your phone number: 2984938
# Enter product ID : 1001
# Enter Quantity   : 3
# --------------------------------------------
#                 BILL
# Name      :  5 Star
# Price (Rs):  10
# Quantity  :  3
# ---------------------------------------------
# Billing Amount   :  30 Rs
# ---------------------------------------------

# %%
sale
# Out:
# '1,muskan,musknan@gmail.com,2984938,1001,5 Star,3,10,30,Thu Mar  6 17:03:40 2025'

# %%
##  NOW GENERATING SALES STRUCTURE IN A FILE
import json
import time


f = open("inventory mgmt sys.json", "r")
js = f.read()
f.close()

record = json.loads(js)
sale=''

print("--------------------MENU---------------------")
for key in record.keys():
    print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
    print("---------------------------------------------")
    print('')

ui_name=input("enter your name      : ")
ui_mail=input("enter your email    : ")
ui_ph=input("enter your phone number: ")

ui_pr = str(input("Enter product ID : "))
ui_qn = int(input("Enter Quantity   : "))


if record[ui_pr]["Qn"] >= ui_qn:
        record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
        print("--------------------------------------------")
        print("                BILL                        ")
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", ui_qn)
        print("---------------------------------------------")
        print("Billing Amount   : ", record[ui_pr]["Price"] * ui_qn, "Rs")
        print("---------------------------------------------")
        sale = '1'+","+ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+str(ui_qn * record[ui_pr]["Price"])+","+time.ctime()+"\n"

        
else:
    print("Sorry, we do not have enough quantity")
    print("We have only", record[ui_pr]["Qn"], "quantity")
    print("---------------------------------------------")
    
    ch = input("Enter y/Y to purchase available stock and press n to leave ")
    
    if ch == "y" or ch == "Y":
        print("--------------------------------------------")
        print("                BILL                        ")
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", record[ui_pr]["Qn"])
        print("---------------------------------------------")
        print("Billing Amount   : ", record[ui_pr]["Price"] * record[ui_pr]["Qn"], "Rs")
        print("---------------------------------------------")
        
        
        record[ui_pr]['Qn'] = 0
        sale =ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(record[ui_pr]['Qn'])+","+str(record[ui_pr]["Price"])+","+str(record[ui_pr]['Qn'] * record[ui_pr]["Price"])+","+time.ctime()+"\n"

        
        
    else:
        print("Thanks")

js = json.dumps(record)
f = open("inventory mgmt sys.json", "w")
f.write(js)
f.close()

f=open("salesTrack.txt","a")
f.write(sale)
f.close()
# Out:
# --------------------MENU---------------------
# 1001 5 Star 10 147
# ---------------------------------------------
#
# 1002 Bar-One 20 50
# ---------------------------------------------
#
# 1003 Candy 2 1000
# ---------------------------------------------
#
# 1004 Chocolate Cake 550 6
# ---------------------------------------------
#
# 1005 Blueberry Cake 650 3
# ---------------------------------------------
#
# enter your name      : avnnet
# enter your email    : avnnet@gmail.com
# enter your phone number: 287428990
# Enter product ID : 1003
# Enter Quantity   : 10
# --------------------------------------------
#                 BILL
# Name      :  Candy
# Price (Rs):  2
# Quantity  :  10
# ---------------------------------------------
# Billing Amount   :  20 Rs
# ---------------------------------------------
